# %%
# https://www.digitalocean.com/community/tutorials/a-guide-to-time-series-forecasting-with-prophet-in-python-3

# %matplotlib inline
import pandas as pd
from fbprophet import Prophet

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\OneDrive - Rajamangala University of Technology Lanna\Workspace\Programs\Data_Sci\Pandas_Project\LinearRegression\Arima_Time Series Forecasting2.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> get_ipython().run_line_magic('matplotlib', 'inline')
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> from fbprophet import Prophet
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> plt.style.use('fivethirtyeight')
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
df = pd.read_csv('AirPassengers.csv')

df.head(5)
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04        1290
# 4  1949-05         121

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\OneDrive - Rajamangala University of Technology Lanna\Workspace\Programs\Data_Sci\Pandas_Project\LinearRegression\Arima_Time Series Forecasting2.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df.dtypes
#
# NameError: name 'df' is not defined

# %%
df['Month'] = pd.DatetimeIndex(df['Month'])
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\OneDrive - Rajamangala University of Technology Lanna\Workspace\Programs\Data_Sci\Pandas_Project\LinearRegression\Arima_Time Series Forecasting2.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df['Month'] = pd.DatetimeIndex(df['Month'])
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df.dtypes
#
# NameError: name 'df' is not defined

# %%
df = df.rename(columns={'Month': 'ds',
                        'AirPassengers': 'y'})

df.head(5)
# Out:
#           ds  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
ax = df.set_index('ds').plot(figsize=(12, 8))
ax.set_ylabel('Monthly Number of Airline Passengers')
ax.set_xlabel('Date')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\OneDrive - Rajamangala University of Technology Lanna\Workspace\Programs\Data_Sci\Pandas_Project\LinearRegression\Arima_Time Series Forecasting2.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> ax.set_ylabel('Monthly Number of Airline Passengers')
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> ax.set_xlabel('Date')
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20Rajamangala%20University%20of%20Technology%20Lanna/Workspace/Programs/Data_Sci/Pandas_Project/LinearRegression/Arima_Time%20Series%20Forecasting2.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> plt.show()
#
# NameError: name 'plt' is not defined
